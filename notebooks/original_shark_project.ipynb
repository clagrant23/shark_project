# %%
import pandas as pd
new_df = pd.read_csv('Shark_attacks.csv', low_memory = False)
new_df.head()
# Out:
#         Date    Year          Type    Country            State  \
# 0  29-May-25  2025.0    Unprovoked        USA   North Carolina
# 1  15-May-25  2025.0    Unprovoked  Australia  South Australia
# 2   8-May-25  2025.0    Unprovoked    Jamaica      Montego Bay
# 3  21-Apr-25  2025.0    Unprovoked     Israel           Hadera
# 4  20-Apr-25  2025.0  Questionable     Mexico      Quntana Roo
#
#                          Location                    Activity  \
# 0                    Sunset Beach                    Swimming
# 1                  Port Noarlunga                    Swimming
# 2                 Rose Hall beach                    Paddling
# 3  Olga Beach near Hadera Stream                       Diving
# 4          Chac Mool Beach Cancun  Rescuing female companion
#
#                Name Sex Age  ... Unnamed: 245 Unnamed: 246 Unnamed: 247  \
# 0       Sean Barton   M  26  ...          NaN          NaN          NaN
# 1    Richard Vinall   M  66  ...          NaN          NaN          NaN
# 2      Rachel Smith   F  26  ...          NaN          NaN          NaN
# 3       Barak Tzach   M  45  ...          NaN          NaN          NaN
# 4  Alejandro Cortes   M  20  ...          NaN          NaN          NaN
#
#   Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
#
#   Unnamed: 253 Unnamed: 254
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 255 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

new_df['Date'] = pd.to_datetime(new_df['Date'], errors='coerce')
new_df['Year'] = new_df['Date'].dt.year

new_df = new_df.dropna(subset=['Year'])


attacks_by_year = new_df.groupby('Year').size().reset_index(name='Attack Count')

attacks_by_year = attacks_by_year[(attacks_by_year['Year'] >= 1900) & (attacks_by_year['Year'] <= 2025)]

plt.figure(figsize=(14, 6))
sns.lineplot(data=attacks_by_year, x='Year', y='Attack Count')
plt.title('Shark Attacks per Year (1900–2025)')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/8m/lr9b5f6x3t7bznx7qlpq71rc0000gn/T/ipykernel_83371/2967110500.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   new_df['Date'] = pd.to_datetime(new_df['Date'], errors='coerce')

# %%
df_aus = new_df[new_df['Country'] == 'Australia']
df_aus.head()
# Out:
#          Date    Year        Type    Country            State  \
# 1  2025-05-15  2025.0  Unprovoked  Australia  South Australia
# 7  2025-03-26  2025.0  Unprovoked  Australia               WA
# 8  2025-03-10  2025.0  Unprovoked  Australia               WA
# 9  2025-03-07  2025.0  Unprovoked  Australia              NSW
# 10 2025-02-27  2025.0  Unprovoked  Australia         Victoria
#
#                                      Location  Activity                  Name  \
# 1                              Port Noarlunga  Swimming        Richard Vinall
# 7   Sandtrax Port Beach North Fremantle Perth  Swimming          Unknown Male
# 8                         Duke of Orleans Bay   Surfing  Steven Jeffrey Payne
# 9          Gunyah beach Bundeena Port Hacking  Swimming        Mangyong Zhang
# 10                   Nuns Beach near Portland  Swimming       Robbie Houlihan
#
#    Sex  Age  ... Unnamed: 245 Unnamed: 246 Unnamed: 247 Unnamed: 248  \
# 1    M   66  ...          NaN          NaN          NaN          NaN
# 7    M  30+  ...          NaN          NaN          NaN          NaN
# 8    M   37  ...          NaN          NaN          NaN          NaN
# 9   F    56  ...          NaN          NaN          NaN          NaN
# 10   M  40+  ...          NaN          NaN          NaN          NaN
#
#    Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252 Unnamed: 253  \
# 1           NaN          NaN          NaN          NaN          NaN
# 7           NaN          NaN          NaN          NaN          NaN
# 8           NaN          NaN          NaN          NaN          NaN
# 9           NaN          NaN          NaN          NaN          NaN
# 10          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 254
# 1           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
#
# [5 rows x 255 columns]

# %%
state_counts = df_aus['State'].value_counts()

print(state_counts)
# Out:
# State
# Western Australia    6
# Queensland           5
# South Australia      3
# NSW                  3
# WA                   2
# Victoria             1
# New South Wales      1
# Name: count, dtype: int64

# %%
df_aus['Date'] = pd.to_datetime(df_aus['Date'], errors='coerce')

df_aus = df_aus.dropna(subset = ['Date'])

df_aus['Year'] = df_aus['Date'].dt.year

attacks_by_year = df_aus.groupby('Year').size().reset_index(name='Attack Count')

attacks_by_year
# Out:
# /var/folders/8m/lr9b5f6x3t7bznx7qlpq71rc0000gn/T/ipykernel_83371/3321168889.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aus['Date'] = pd.to_datetime(df_aus['Date'], errors='coerce')
#    Year  Attack Count
# 0  2017             1
# 1  2024             8
# 2  2025            12

# %%
df_usa = new_df[new_df['Country'] == 'USA']
df_usa.head()
# Out:
#          Date    Year        Type Country           State  \
# 0  2025-05-29  2025.0  Unprovoked     USA  North Carolina
# 6  2025-04-12  2025.0  Unprovoked     USA         Florida
# 22 2025-01-11  2025.0    Provoked     USA          Hawaii
# 36 2024-10-25  2024.0  Unprovoked     USA         Florida
# 38 2024-10-11  2024.0  Unprovoked     USA         Florida
#
#                                              Location     Activity  \
# 0                                        Sunset Beach     Swimming
# 6   Everglades National Park Flamingo Lodge Highwa...  Undisclosed
# 22                      Off Haleiwa Boat Harbour Oahu       Diving
# 36                       Bathtub Beach, Martin County      Surfing
# 38                             Brevard County Orlando      Surfing
#
#                                       Name Sex Age  ... Unnamed: 245  \
# 0                              Sean Barton   M  26  ...          NaN
# 6                             Unknown Male   M   ?  ...          NaN
# 22  Male not stated was a dive tour worker   M  23  ...          NaN
# 36                           Cole Taschman   M  27  ...          NaN
# 38                          Teddy Witteman   M  16  ...          NaN
#
#    Unnamed: 246 Unnamed: 247 Unnamed: 248 Unnamed: 249 Unnamed: 250  \
# 0           NaN          NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN          NaN
# 36          NaN          NaN          NaN          NaN          NaN
# 38          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 251 Unnamed: 252 Unnamed: 253 Unnamed: 254
# 0           NaN          NaN          NaN          NaN
# 6           NaN          NaN          NaN          NaN
# 22          NaN          NaN          NaN          NaN
# 36          NaN          NaN          NaN          NaN
# 38          NaN          NaN          NaN          NaN
#
# [5 rows x 255 columns]

# %%
df_florida = df_usa[df_usa['State'] == 'Florida']
df_florida.head()
# Out:
#          Date    Year        Type Country    State  \
# 6  2025-04-12  2025.0  Unprovoked     USA  Florida
# 36 2024-10-25  2024.0  Unprovoked     USA  Florida
# 38 2024-10-11  2024.0  Unprovoked     USA  Florida
# 46 2024-07-08  2024.0  Unprovoked     USA  Florida
# 47 2024-07-05  2024.0  Unprovoked     USA  Florida
#
#                                              Location           Activity  \
# 6   Everglades National Park Flamingo Lodge Highwa...        Undisclosed
# 36                       Bathtub Beach, Martin County            Surfing
# 38                             Brevard County Orlando            Surfing
# 46                 Ponce de Leon Inlet Volusia County  Diving into Water
# 47                                   New Smyrna Beach             Wading
#
#                Name Sex Age  ... Unnamed: 245 Unnamed: 246 Unnamed: 247  \
# 6      Unknown Male   M   ?  ...          NaN          NaN          NaN
# 36    Cole Taschman   M  27  ...          NaN          NaN          NaN
# 38   Teddy Witteman   M  16  ...          NaN          NaN          NaN
# 46  Dempsey Manhart   M  14  ...          NaN          NaN          NaN
# 47       Not stated   M  26  ...          NaN          NaN          NaN
#
#    Unnamed: 248 Unnamed: 249 Unnamed: 250 Unnamed: 251 Unnamed: 252  \
# 6           NaN          NaN          NaN          NaN          NaN
# 36          NaN          NaN          NaN          NaN          NaN
# 38          NaN          NaN          NaN          NaN          NaN
# 46          NaN          NaN          NaN          NaN          NaN
# 47          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 253 Unnamed: 254
# 6           NaN          NaN
# 36          NaN          NaN
# 38          NaN          NaN
# 46          NaN          NaN
# 47          NaN          NaN
#
# [5 rows x 255 columns]

# %%
df_florida['Date'] = pd.to_datetime(df_florida['Date'], errors='coerce')

df_florida = df_florida.dropna(subset = ['Date'])

df_florida['Year'] = df_florida['Date'].dt.year

attacks_by_year = df_florida.groupby('Year').size().reset_index(name='Attack Count')

attacks_by_year
# Out:
# /var/folders/8m/lr9b5f6x3t7bznx7qlpq71rc0000gn/T/ipykernel_83371/3145824425.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_florida['Date'] = pd.to_datetime(df_florida['Date'], errors='coerce')
#      Year  Attack Count
# 0    1780             1
# 1    1849             2
# 2    1857             1
# 3    1881             1
# 4    1882             1
# ..    ...           ...
# 102  2021            30
# 103  2022            24
# 104  2023            22
# 105  2024             7
# 106  2025             1
#
# [107 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

attacks_by_year = attacks_by_year[(attacks_by_year['Year'] >= 1900) & (attacks_by_year['Year'] <= 2025)]

plt.figure(figsize=(14, 6))
sns.lineplot(data=attacks_by_year, x='Year', y='Attack Count')
plt.title('Shark Attacks per Year in Florida (1900–2018)')
plt
# Out:
# <module 'matplotlib.pyplot' from '/Users/claygrant/Documents/my_data_project/jhub_env/lib/python3.9/site-packages/matplotlib/pyplot.py'>

# %%
sst_df = pd.read_csv("sst.csv")

sst_df.head()
# Out:
#                    time zlev       latitude     longitude       sst      anom  \
# 0                   UTC    m  degrees_north  degrees_east  degree_C  degree_C
# 1  2020-04-26T12:00:00Z  0.0        -87.375        24.125       NaN       NaN
# 2  2020-04-26T12:00:00Z  0.0        -87.375        24.375       NaN       NaN
# 3  2020-04-26T12:00:00Z  0.0        -87.375        24.625       NaN       NaN
# 4  2020-04-26T12:00:00Z  0.0        -87.375        24.875       NaN       NaN
#
#         err  ice
# 0  degree_C  1.0
# 1       NaN  NaN
# 2       NaN  NaN
# 3       NaN  NaN
# 4       NaN  NaN

# %%
import pandas as pd
import matplotlib.pyplot as plt

population_df = pd.read_csv("florida_population_1960_2024.csv")

merged_df = pd.merge(attacks_by_year, population_df, on="Year")

merged_df["Attacks_per_100k"] = (merged_df["Attack Count"] / merged_df["Population"]) * 100000

plt.figure(figsize=(12, 6))
plt.plot(merged_df["Year"], merged_df["Attacks_per_100k"], marker='o', linestyle='-', color='teal')
plt.title("Shark Attacks per 100k People in Florida (1960–2024)")
plt.xlabel("Year")
plt.ylabel("Attacks per 100,000 Residents")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd

temp_df = pd.read_csv("global_temps.csv")

temp_df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.19 -0.25 -0.09 -0.17 -0.10 -0.21 -0.18 -0.11 -0.15 -0.24 -0.22
# 1  1881 -0.20 -0.15  0.03  0.05  0.05 -0.19  0.00 -0.04 -0.16 -0.22 -0.19
# 2  1882  0.16  0.13  0.04 -0.16 -0.14 -0.22 -0.17 -0.08 -0.15 -0.24 -0.17
# 3  1883 -0.30 -0.37 -0.13 -0.19 -0.18 -0.08 -0.08 -0.14 -0.23 -0.12 -0.24
# 4  1884 -0.13 -0.09 -0.37 -0.40 -0.34 -0.35 -0.31 -0.28 -0.28 -0.25 -0.34
#
#     Dec   J-D   D-N   DJF   MAM   JJA   SON
# 0 -0.18 -0.17   NaN   NaN -0.12 -0.17 -0.20
# 1 -0.08 -0.09 -0.10 -0.18  0.04 -0.08 -0.19
# 2 -0.36 -0.11 -0.09  0.07 -0.09 -0.16 -0.19
# 3 -0.11 -0.18 -0.20 -0.34 -0.17 -0.10 -0.20
# 4 -0.31 -0.29 -0.27 -0.11 -0.37 -0.32 -0.29

# %%
import pandas as pd
import matplotlib.pyplot as plt

temp_df = pd.read_csv("global_temps.csv")

temp_df = temp_df[["Year", "J-D"]].dropna()

temp_df.rename(columns={"J-D": "Global_Temp_Anomaly"}, inplace=True)

plt.figure(figsize=(12, 6))
plt.plot(temp_df["Year"], temp_df["Global_Temp_Anomaly"], color='crimson', linewidth=2)
plt.title("Global Temperature Anomalies (Jan–Dec Avg, °C) Over Time", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Temperature Anomaly (°C)", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sst_merged_df = pd.merge(attacks_by_year, temp_df, on="Year")

fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.plot(sst_merged_df["Year"], sst_merged_df["Attack Count"], color='red', label='Shark Attacks')
ax1.set_xlabel("Year")
ax1.set_ylabel("Shark Attacks", color='red')
ax1.tick_params(axis='y', labelcolor='red')

ax2 = ax1.twinx()
ax2.plot(sst_merged_df["Year"], sst_merged_df["Global_Temp_Anomaly"], color='blue', label='Temp Anomaly')
ax2.set_ylabel("Temp Anomaly (°C)", color='blue')
ax2.tick_params(axis='y', labelcolor='blue')

plt.title("Global Shark Attacks and Temperature Anomalies Over Time")
fig.tight_layout()
plt.show()
